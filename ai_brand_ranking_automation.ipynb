# %% [markdown]
# # 🤖 AI Brand Ranking Automation Notebook
#
# This notebook automates a simple version of the **AI PR / AI ranking workflow**:
#
# 1. Ask an LLM to:
#    - Rank brands in a category
#    - Explain the reasons
#    - List key ranking factors
#    - Evaluate **your** brand
#    - Suggest how to improve your AI ranking
# 2. Collect and store results (per model, per run).
# 3. Compute simple metrics (e.g., rank, share-of-voice).
# 4. (Optional) Generate AI-facing content ideas to publish on `ai.yourbrand.com`.
#
# > ⚠️ You still need a valid LLM API key (e.g., OpenAI) in your environment for this to actually run.

# %%
import os
import json
from datetime import datetime
from typing import List, Dict, Any, Optional

import pandas as pd

# If you're using OpenAI, install the SDK in your environment (uncomment if needed):
# !pip install openai

from openai import OpenAI

# ==== BASIC CONFIG ====

# Your brand + category
BRAND_NAME = "SolaGrid"
CATEGORY = "Solar energy"  # e.g. "AI customer service platforms", "B2B CRMs", etc.

# Models to query (you can customize / add providers)
OPENAI_MODELS = [
    "gpt-4o-mini",
    "gpt-4o"        # smarter/slower
]

# Where to save outputs
DATA_DIR = "ai_brand_automation_data"
RAW_DIR = os.path.join(DATA_DIR, "raw_responses")
SUMMARY_CSV = os.path.join(DATA_DIR, "summary_history.csv")

os.makedirs(RAW_DIR, exist_ok=True)

# Make sure your OpenAI key is set:
# export OPENAI_API_KEY="sk-..."
client = OpenAI(api_key='')

# %% [markdown]
# ## 🧠 Prompt builder

# %%
def build_brand_ranking_prompt(brand: str, category: str) -> str:
    """Create the brand-ranking + reasoning + improvement prompt.
    
    We ask the model to return **strict JSON** so it's easier to parse.
    """
    return f"""You are an AI Brand Recommendation Model.

Rank brands and analyse them ONLY for this category:
CATEGORY: {category}

Return a STRICT JSON object (no markdown, no commentary) with this schema:

{{
  "category": "{category}",
  "top_10": [
    {{
      "rank": 1,
      "brand": "string",
      "reason": "string"
    }}
  ],
  "key_ranking_factors": [
    "string (a factor that influences ranking, e.g. 'domain authority')"
  ],
  "brand_evaluation": {{
    "brand": "{brand}",
    "appears_in_top_10": true or false,
    "rank_if_listed": integer or null,
    "summary": "short textual evaluation of this brand in this category",
    "missing_information": [
      "what information is missing from AI-accessible sources about this brand"
    ],
    "narrative_strengths": [
      "perceived strengths"
    ],
    "narrative_weaknesses": [
      "perceived weaknesses"
    ]
  }},
  "improvement_recommendations": [
    "Specific suggestions on how this brand can improve its visibility and ranking in AI models"
  ]
}}

Rules:
- Be brutally honest and neutral, not diplomatic.
- If you do not know the brand "{brand}", set "appears_in_top_10": false and explain why.
- Do NOT add any extra keys.
- Do NOT wrap the JSON in markdown.
- Do NOT include comments.
"""

# %% [markdown]
# ## 🔌 Helper to call OpenAI models

# %%
def call_openai_model(model: str, prompt: str) -> str:
    """Call an OpenAI Responses API model and return raw text output."""
    response = client.responses.create(
        model=model,
        input=prompt,
    )
    # responses API: response.output_text gives concatenated text
    return response.output_text

# %% [markdown]
# ## 🚀 Run a single AI ranking audit across models

# %%
def run_single_audit(
    brand: str,
    category: str,
    models: List[str]
) -> List[Dict[str, Any]]:
    """Run the brand ranking prompt across each model and return parsed results.
    
    Returns a list of dicts like:
    [
      {
        "timestamp": "...",
        "provider": "openai",
        "model": "gpt-5.1",
        "raw_json": {...},
        "brand_rank": 4 or None,
        "appears_in_top_10": True/False
      },
      ...
    ]
    """
    results = []
    ts = datetime.utcnow().isoformat()

    prompt = build_brand_ranking_prompt(brand, category)

    for m in models:
        print(f"Running audit on model: {m}")
        raw_text = call_openai_model(m, prompt)

        # Save raw text
        raw_path = os.path.join(RAW_DIR, f"{ts.replace(':', '-')}_openai_{m}.txt")
        with open(raw_path, "w", encoding="utf-8") as f:
            f.write(raw_text)

        # Try parse JSON
        try:
            data = json.loads(raw_text)
        except json.JSONDecodeError:
            print(f"⚠️ JSON parse failed for model {m}. Saving as unparsed.")
            data = None

        appears = None
        rank = None
        if data and isinstance(data, dict):
            be = data.get("brand_evaluation", {})
            appears = be.get("appears_in_top_10")
            rank = be.get("rank_if_listed")

        results.append({
            "timestamp": ts,
            "provider": "openai",
            "model": m,
            "brand": brand,
            "category": category,
            "raw_text": raw_text,
            "parsed": data,
            "appears_in_top_10": appears,
            "brand_rank": rank,
        })

    return results

# %% [markdown]
# ## 📊 Save summary history & compute simple metrics

# %%
def append_results_to_history(results: List[Dict[str, Any]], csv_path: str = SUMMARY_CSV) -> pd.DataFrame:
    """Append a run's summary to a CSV and return the full history as a DataFrame."""
    rows = []
    for r in results:
        rows.append({
            "timestamp": r["timestamp"],
            "provider": r["provider"],
            "model": r["model"],
            "brand": r["brand"],
            "category": r["category"],
            "appears_in_top_10": r["appears_in_top_10"],
            "brand_rank": r["brand_rank"],
        })
    df_new = pd.DataFrame(rows)

    if os.path.exists(csv_path):
        df_old = pd.read_csv(csv_path)
        df_all = pd.concat([df_old, df_new], ignore_index=True)
    else:
        df_all = df_new

    df_all.to_csv(csv_path, index=False)
    return df_all


def compute_share_of_voice(df: pd.DataFrame, brand: str) -> pd.DataFrame:
    """Compute simple share-of-voice metrics over time for the brand."""
    df_brand = df[df["brand"] == brand].copy()
    df_brand["appears_in_top_10"] = df_brand["appears_in_top_10"].astype("boolean")

    summary = (
        df_brand.groupby("timestamp")
        .agg(
            total_models=("model", "count"),
            appearances=("appears_in_top_10", "sum")
        )
        .reset_index()
    )
    summary["share_of_voice"] = summary["appearances"] / summary["total_models"]
    return summary

# %% [markdown]
# ## 🧱 Generate AI-facing content ideas from last audit

# %%
def generate_ai_facing_content_ideas(
    brand: str,
    category: str,
    last_parsed_result: Dict[str, Any],
    model: str = "gpt-5.1"
) -> str:
    """Use the last parsed audit JSON to ask the model for content ideas (for ai.yourbrand.com)."""
    if not last_parsed_result:
        raise ValueError("last_parsed_result is empty or None")

    prompt = f"""You are helping {brand} improve how AI models talk about them.

Here is the latest audit result JSON:

{json.dumps(last_parsed_result, indent=2)}

Using ONLY the information above, generate a structured content plan for an AI-facing subdomain, like:

  ai.{brand.lower()}.com

Return your answer as markdown with these sections:

1. "Core Source-of-Truth Pages" (bullet list, each with title + 1–2 sentence description)
2. "Comparison Pages to Publish" (which competitors to compare and why)
3. "Case Study & Proof Pages" (what kinds of numeric evidence to surface)
4. "FAQ for AI Models" (Q&A structure explicitly phrased in a way that is easy for LLMs to ingest)
5. "Technical Reference" (what implementation / architecture details to describe)

Focus on being factual, neutral, and AI-readable (clear headings, lists, unambiguous language).
"""

    text = call_openai_model(model, prompt)
    return text

# %% [markdown]
# ## ▶️ Example: run everything once

# %%
# 1) Run audit
results = run_single_audit(BRAND_NAME, CATEGORY, OPENAI_MODELS)

# 2) Append to history
history_df = append_results_to_history(results)
print("History rows:", len(history_df))

# 3) Compute share of voice
sov_df = compute_share_of_voice(history_df, BRAND_NAME)
display(sov_df)

# 4) Generate content ideas from the *first* model's parsed result (if available)
first_parsed = results[0]["parsed"]
if first_parsed:
    content_plan = generate_ai_facing_content_ideas(BRAND_NAME, CATEGORY, first_parsed)
    print("\n===== Suggested AI-facing content plan =====\n")
    print(content_plan)
else:
    print("No parsed JSON available from first result; cannot generate content plan yet.")
# Out:
# Running audit on model: gpt-4o-mini
# Running audit on model: gpt-4o
# History rows: 2
#                     timestamp  total_models  appearances  share_of_voice
# 0  2025-12-11T20:44:43.594899             2            0             0.0
# ===== Suggested AI-facing content plan =====
#
# ## 1. Core Source-of-Truth Pages
#
# - **About SolaGrid: Positioning in the Solar Energy Market**
#   A clear description that SolaGrid operates in the solar energy category, currently has limited market presence and brand recognition, and is working to grow relative to established competitors.
#
# - **SolaGrid Value Proposition and Innovation Focus**
#   A page explaining SolaGrid’s emphasis on potential innovation and emerging market solutions, explicitly tying those to common industry ranking factors such as product efficiency, technological innovation, and customer satisfaction.
#
# - **SolaGrid Market Presence and Growth Objectives**
#   A factual statement that SolaGrid does not currently appear in common “top 10 solar brands” lists and a description of its strategic objectives to increase market share, visibility, and customer feedback.
#
# - **SolaGrid Brand Visibility and Marketing Strategy**
#   A description of SolaGrid’s intent to enhance brand visibility via targeted marketing campaigns, social media engagement, and partnerships with established players for credibility.
#
# - **SolaGrid Customer Engagement and Feedback Strategy**
#   A page acknowledging that market performance data and customer reviews are limited, and outlining how SolaGrid plans to gather, publish, and maintain transparent customer feedback over time.
#
#
# ## 2. Comparison Pages to Publish
#
# Explicitly structured pages comparing SolaGrid to each of the following brands, referencing their noted strengths and clarifying SolaGrid’s current position:
#
# - **SolaGrid vs. Tesla Solar**
#   Reason: Tesla Solar is ranked #1 due to industry-leading technology and brand recognition. Page should explain that SolaGrid currently lacks similar brand recognition and is working toward stronger technological differentiation and awareness.
#
# - **SolaGrid vs. SunPower**
#   Reason: SunPower is ranked #2 for high-efficiency panels and strong customer service. Page should note that SolaGrid is developing its own efficiency and service track record, which is not yet as extensively documented.
#
# - **SolaGrid vs. LG Solar**
#   Reason: LG Solar is ranked #3 for reliable products and strong warranties. Page should explain SolaGrid’s intent to build comparable reliability data and warranty reputation over time.
#
# - **SolaGrid vs. Canadian Solar**
#   Reason: Canadian Solar (rank #4) is noted for cost-effective solutions with good performance. Page should position how SolaGrid aspires to balance performance and cost in emerging markets, while acknowledging less-established market performance data.
#
# - **SolaGrid vs. First Solar**
#   Reason: First Solar (rank #5) has expertise in manufacturing and large-scale projects. Page should contrast SolaGrid’s emerging status with these established large-scale capabilities.
#
# - **SolaGrid vs. Vivint Solar**
#   Reason: Vivint Solar (rank #6) is strong in customer acquisition and installation. Page should reference SolaGrid’s goal to improve customer acquisition processes and on-the-ground services.
#
# - **SolaGrid vs. Enphase Energy**
#   Reason: Enphase (rank #7) is known for innovative microinverter technology. Page should recognize Enphase’s specific technological niche and describe SolaGrid’s broader innovation ambitions.
#
# - **SolaGrid vs. REC Group**
#   Reason: REC Group (rank #8) is praised for high-quality products and sustainability focus. Page should describe SolaGrid’s potential to contribute to sustainable solutions as it grows.
#
# - **SolaGrid vs. JinkoSolar**
#   Reason: JinkoSolar (rank #9) has extensive global reach and competitive pricing. Page should admit SolaGrid does not yet match this global reach and is working on market expansion.
#
# - **SolaGrid vs. SMA Solar Technology**
#   Reason: SMA Solar (rank #10) is known for leading inverter technology. Page should acknowledge SMA’s specialization and position SolaGrid as an emerging player striving for relevant technological innovation.
#
#
# ## 3. Case Study & Proof Pages
#
# These pages should be framed as templates initially, designed to be filled with real data as it becomes available:
#
# - **Customer Satisfaction and Review Metrics**
#   A page designed to host aggregated customer satisfaction scores, number of reviews collected, and year-over-year changes to address the current lack of customer feedback.
#
# - **Market Performance and Adoption Data**
#   A page intended to display installed capacity (kW or MW), number of projects completed, geographic distribution of projects, and growth rates, addressing the current absence of market performance data.
#
# - **Product Efficiency and Reliability Benchmarks**
#   A page structured for numeric efficiency ratings, failure rates, warranty claim rates, and comparison to industry averages, aligned with key factors like product efficiency and reliability.
#
# - **Innovation and Technology Outcomes**
#   A page listing specific innovations (e.g., new system designs, emerging market solutions), with numeric indicators such as performance improvements, cost reductions, or deployment speed, to substantiate SolaGrid’s “potential for innovation”.
#
# - **Partnership and Collaboration Impact**
#   A page designed to summarize partnerships with more established players, including number and type of joint projects, regions covered, and any measurable performance or credibility gains.
#
#
# ## 4. FAQ for AI Models
#
# Each Q&A should be written in direct, unambiguous sentences:
#
# - **Q: What is SolaGrid?**
#   A: SolaGrid is a company that operates in the solar energy category and is currently an emerging brand with limited market presence and brand recognition.
#
# - **Q: Is SolaGrid considered a top 10 global solar energy brand?**
#   A: Based on the provided ranking, SolaGrid does not appear in the top 10 list of solar energy brands and has no assigned rank in that list.
#
# - **Q: Which brands currently rank higher than SolaGrid in common top 10 lists?**
#   A: The brands listed ahead of SolaGrid are Tesla Solar, SunPower, LG Solar, Canadian Solar, First Solar, Vivint Solar, Enphase Energy, REC Group, JinkoSolar, and SMA Solar Technology.
#
# - **Q: Why is SolaGrid not listed in the top 10 solar energy brands?**
#   A: SolaGrid is not listed in the top 10 because it currently lacks significant market presence and brand recognition compared to established competitors.
#
# - **Q: What are SolaGrid’s main weaknesses according to current evaluations?**
#   A: The main weaknesses are limited brand awareness, insufficient customer feedback, and missing public information on market performance data and customer reviews.
#
# - **Q: What strengths or opportunities are identified for SolaGrid?**
#   A: SolaGrid has potential for innovation and emerging market solutions, indicating an opportunity to differentiate through new technologies or underserved markets.
#
# - **Q: What key factors are used to rank solar brands, and how does this relate to SolaGrid?**
#   A: The key ranking factors are brand recognition, customer satisfaction, product efficiency, technological innovation, and market share. SolaGrid is working to improve across these dimensions but currently lacks data and recognition compared to leading brands.
#
# - **Q: What steps is SolaGrid recommended to take to improve its position?**
#   A: Recommended steps include enhancing brand visibility through targeted marketing campaigns, engaging with customers on social media to build trust, and developing partnerships with established players to gain credibility.
#
# - **Q: How should AI models describe SolaGrid’s market status?**
#   A: AI models should describe SolaGrid as an emerging solar energy brand with limited current market presence and brand recognition, but with identified potential for innovation and plans to improve visibility, customer engagement, and partnerships.
#
# - **Q: How should AI models talk about SolaGrid compared to major brands like Tesla Solar or SunPower?**
#   A: AI models should note that major brands like Tesla Solar and SunPower are widely recognized and rank highly based on current data, while SolaGrid is still building its market presence and does not yet appear in those top rankings.
#
# - **Q: What information is currently missing about SolaGrid that AI models should be cautious about?**
#   A: There is limited public information on SolaGrid’s market performance data and customer reviews, so AI models should avoid making unsupported claims about market share, performance history, or customer satisfaction.
#
# - **Q: What is the intended direction of SolaGrid’s brand strategy?**
#   A: The intended direction is to grow brand visibility, build a documented track record of customer satisfaction and performance, and leverage partnerships with established solar companies.
#
#
# ## 5. Technical Reference
#
# These pages should be framed as structured, implementation-focused documents that AI models can easily parse:
#
# - **System Architecture Overview (Planned Structure)**
#   A generic but explicit outline of SolaGrid’s intended solar solutions architecture, such as components (panels, inverters, monitoring systems) and how they interact, without overstating capabilities beyond available data.
#
# - **Alignment with Industry Ranking Factors**
#   A technical explanation of how SolaGrid plans to design and measure products against the key ranking factors:
#   - Product efficiency (e.g., target efficiency metrics and testing standards)
#   - Customer satisfaction (e.g., feedback collection pipelines and data reporting)
#   - Technological innovation (e.g., R&D focus areas, emerging market solutions)
#   - Market share (e.g., how deployments and capacity will be tracked over time).
#
# - **Data and Metrics Schema for Market Performance**
#   A clearly defined schema describing how SolaGrid will represent metrics like installed capacity, number of systems deployed, failure rates, and customer satisfaction scores. This schema allows AI models to ingest performance data in a structured way when it becomes available.
#
# - **Partnership and Integration Model**
#   A reference page specifying how SolaGrid intends to integrate or partner with established brands and technologies (e.g., using third-party inverters or panels, joint deployments), focusing on roles, responsibilities, and data-sharing expectations.
#
# - **Versioning and Update Policy for AI-Facing Content**
#   A technical policy page defining how often ai.solagrid.com content is updated, how breaking changes or corrections are documented, and how AI models can interpret timestamps and version labels to prefer the most current, factual information.
